# %%
# HTML to Strapi Schema Plan

#This notebook tests the AI agent MVP flow:

#HTML page → section detection → CMS plan generation → validation report

# %%
from pathlib import Path
import json
import sys

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src.section_detector import analyze_html_file
from src.schema_planner import llm_section_planner_node
from src.schema_validator import validate_cms_plan

# %%
sample_html_path = Path("sample-html/landing-page-1.html")
sample_html_path.exists()
# Out:
# True

# %%
analysis = analyze_html_file(sample_html_path)
print(json.dumps(analysis["page"], indent=2))
# Out:
# {
#   "title": "LaunchFlow - Modern Landing Page Platform",
#   "rootTag": "main",
#   "sectionCount": 6
# }

# %%
section_summary = [
    {
        "index": section["index"],
        "semanticHint": section["semanticHint"],
        "heading": section["heading"],
        "signals": section["structureSignals"],
    }
    for section in analysis["candidateSections"]
]

print(json.dumps(section_summary, indent=2))
# Out:
# [
#   {
#     "index": 1,
#     "semanticHint": "hero",
#     "heading": "Build beautiful landing pages without rebuilding your CMS",
#     "signals": {
#       "hasButtons": true,
#       "hasCards": false,
#       "hasTable": false,
#       "hasFaqPattern": false,
#       "hasForm": false,
#       "hasImages": true,
#       "childBlockCount": 2
#     }
#   },
#   {
#     "index": 2,
#     "semanticHint": "feature",
#     "heading": "Everything your team needs to launch",
#     "signals": {
#       "hasButtons": false,
#       "hasCards": true,
#       "hasTable": false,
#       "hasFaqPattern": false,
#       "hasForm": false,
#       "hasImages": false,
#       "childBlockCount": 3
#     }
#   },
#   {
#     "index": 3,
#     "semanticHint": "testimonial",
#     "heading": "Trusted by growing teams",
#     "signals": {
#       "hasButtons": false,
#       "hasCards": true,
#       "hasTable": false,
#       "hasFaqPattern": false,
#       "hasForm": false,
#       "hasImages": false,
#       "childBlockCount": 2
#     }
#   },
#   {
#     "index": 4,
#     "semanticHint": "pricing",
#     "heading": "Simple pricing for every stage",
#     "signals": {
#       "hasButtons": false,
#       "hasCards": true,
#       "hasTable": false,
#       "hasFaqPattern": false,
#       "hasForm": false,
#       "hasImages": false,
#       "childBlockCount": 2
#     }
#   },
#   {
#     "index": 5,
#     "semanticHint": "faq",
#     "heading": "Frequently asked questions",
#     "signals": {
#       "hasButtons": false,
#       "hasCards": true,
#       "hasTable": false,
#       "hasFaqPattern": true,
#       "hasForm": false,
#       "hasImages": false,
#       "childBlockCount": 2
#     }
#   },
#   {
#     "index": 6,
#     "semanticHint": "contact",
#     "heading": "Talk to our team",
#     "signals": {
#       "hasButtons": true,
#       "hasCards": false,
#       "hasTable": false,
#       "hasFaqPattern": false,
#       "hasForm": true,
#       "hasImages": false,
#       "childBlockCount": 3
#     }
#   }
# ]

# %%
state = llm_section_planner_node({
    "html_analysis": analysis,
    "errors": [],
})

if state.get("errors"):
    raise RuntimeError(state["errors"])

cms_plan = state["cms_plan"]
print(json.dumps(cms_plan["pageModel"], indent=2))
# Out:
# {
#   "kind": "singleType",
#   "apiName": "launch-flow-landing-page",
#   "displayName": "LaunchFlow Landing Page",
#   "singularName": "launch-flow-landing-page",
#   "pluralName": "launch-flow-landing-pages",
#   "description": "Single type for the LaunchFlow marketing landing page."
# }

# %%
validation_report = validate_cms_plan(cms_plan)
print(json.dumps(validation_report, indent=2))
# Out:
# {
#   "isValid": true,
#   "errors": [],
#   "warnings": [
#     "landing-page.pricing-card.features: repeatable scalar fields may need a repeatable component in Strapi",
#     "globalBlocks.header: componentPlan is not set",
#     "globalBlocks.footer: componentPlan is not set",
#     "Contact form fields are stored as structured JSON in the contact component; Strapi does not natively model dynamic form field schemas, so consider a dedicated form builder or custom component if field-level editing is required.",
#     "Added missing seo singleTypeAttribute for seedData.seo."
#   ],
#   "summary": {
#     "pageApiName": "launch-flow-landing-page",
#     "componentCount": 10,
#     "singleTypeAttributeCount": 7,
#     "seedDataKeyCount": 7,
#     "componentUids": [
#       "landing-page.hero",
#       "landing-page.feature-card",
#       "landing-page.features",
#       "landing-page.testimonial-card",
#       "landing-page.testimonials",
#       "landing-page.pricing-card",
#       "landing-page.pricing",
#       "landing-page.faq-item",
#       "landing-page.faq",
#       "landing-page.contact"
#     ],
#     "singleTypeAttributes": [
#       "seo",
#       "hero",
#       "features",
#       "testimonials",
#       "pricing",
#       "faq",
#       "contact"
#     ],
#     "seedDataKeys": [
#       "seo",
#       "hero",
#       "features",
#       "testimonials",
#       "pricing",
#       "faq",
#       "contact"
#     ]
#   }
# }

# %%
components_summary = [
    {
        "uid": component["uid"],
        "fields": [field["name"] for field in component["fields"]],
    }
    for component in cms_plan["components"]
]

print(json.dumps(components_summary, indent=2))
# Out:
# [
#   {
#     "uid": "landing-page.hero",
#     "fields": [
#       "eyebrow",
#       "title",
#       "description",
#       "primary_cta_label",
#       "primary_cta_href",
#       "secondary_cta_label",
#       "secondary_cta_href",
#       "image"
#     ]
#   },
#   {
#     "uid": "landing-page.feature-card",
#     "fields": [
#       "title",
#       "description"
#     ]
#   },
#   {
#     "uid": "landing-page.features",
#     "fields": [
#       "title",
#       "description",
#       "feature_cards"
#     ]
#   },
#   {
#     "uid": "landing-page.testimonial-card",
#     "fields": [
#       "quote",
#       "author_name",
#       "author_role"
#     ]
#   },
#   {
#     "uid": "landing-page.testimonials",
#     "fields": [
#       "title",
#       "testimonial_cards"
#     ]
#   },
#   {
#     "uid": "landing-page.pricing-card",
#     "fields": [
#       "title",
#       "price",
#       "description",
#       "features",
#       "is_highlighted"
#     ]
#   },
#   {
#     "uid": "landing-page.pricing",
#     "fields": [
#       "title",
#       "pricing_cards"
#     ]
#   },
#   {
#     "uid": "landing-page.faq-item",
#     "fields": [
#       "question",
#       "answer"
#     ]
#   },
#   {
#     "uid": "landing-page.faq",
#     "fields": [
#       "title",
#       "faq_items"
#     ]
#   },
#   {
#     "uid": "landing-page.contact",
#     "fields": [
#       "title",
#       "description",
#       "form_action",
#       "form_method",
#       "submit_label"
#     ]
#   }
# ]

# %%
print(json.dumps(cms_plan, indent=2))
# Out:
# {
#   "pageModel": {
#     "kind": "singleType",
#     "apiName": "launch-flow-landing-page",
#     "displayName": "LaunchFlow Landing Page",
#     "singularName": "launch-flow-landing-page",
#     "pluralName": "launch-flow-landing-pages",
#     "description": "Single type for the LaunchFlow marketing landing page."
#   },
#   "seo": {
#     "enabled": true,
#     "component": "shared.seo"
#   },
#   "globalBlocks": {
#     "header": {
#       "handling": "global_single_type",
#       "apiName": "global-header",
#       "componentPlan": null
#     },
#     "footer": {
#       "handling": "global_single_type",
#       "apiName": "global-footer",
#       "componentPlan": null
#     }
#   },
#   "components": [
#     {
#       "uid": "landing-page.hero",
#       "category": "landing-page",
#       "displayName": "Hero",
#       "fileName": "hero",
#       "fields": [
#         {
#           "name": "eyebrow",
#           "type": "string",
#           "required": false,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "title",
#           "type": "string",
#           "required": true,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "description",
#           "type": "text",
#           "required": false,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "primary_cta_label",
#           "type": "string",
#           "required": false,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "primary_cta_href",
#           "type": "string",
#           "required": false,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "secondary_cta_label",
#           "type": "string",
#           "required": false,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "secondary_cta_href",
#           "type": "string",
#           "required": false,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "image",
#           "type": "media",
#           "required": false,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": [
#             "images"
#           ]
#         }
#       ]
#     },
#     {
#       "uid": "landing-page.feature-card",
#       "category": "landing-page",
#       "displayName": "Feature Card",
#       "fileName": "feature-card",
#       "fields": [
#         {
#           "name": "title",
#           "type": "string",
#           "required": true,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "description",
#           "type": "text",
#           "required": false,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         }
#       ]
#     },
#     {
#       "uid": "landing-page.features",
#       "category": "landing-page",
#       "displayName": "Features",
#       "fileName": "features",
#       "fields": [
#         {
#           "name": "title",
#           "type": "string",
#           "required": true,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "description",
#           "type": "text",
#           "required": false,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "feature_cards",
#           "type": "component",
#           "required": false,
#           "component": "landing-page.feature-card",
#           "repeatable": true,
#           "multiple": false,
#           "allowedTypes": null
#         }
#       ]
#     },
#     {
#       "uid": "landing-page.testimonial-card",
#       "category": "landing-page",
#       "displayName": "Testimonial Card",
#       "fileName": "testimonial-card",
#       "fields": [
#         {
#           "name": "quote",
#           "type": "text",
#           "required": true,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "author_name",
#           "type": "string",
#           "required": true,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "author_role",
#           "type": "string",
#           "required": false,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         }
#       ]
#     },
#     {
#       "uid": "landing-page.testimonials",
#       "category": "landing-page",
#       "displayName": "Testimonials",
#       "fileName": "testimonials",
#       "fields": [
#         {
#           "name": "title",
#           "type": "string",
#           "required": true,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "testimonial_cards",
#           "type": "component",
#           "required": false,
#           "component": "landing-page.testimonial-card",
#           "repeatable": true,
#           "multiple": false,
#           "allowedTypes": null
#         }
#       ]
#     },
#     {
#       "uid": "landing-page.pricing-card",
#       "category": "landing-page",
#       "displayName": "Pricing Card",
#       "fileName": "pricing-card",
#       "fields": [
#         {
#           "name": "title",
#           "type": "string",
#           "required": true,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "price",
#           "type": "string",
#           "required": true,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "description",
#           "type": "text",
#           "required": false,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "features",
#           "type": "text",
#           "required": false,
#           "component": null,
#           "repeatable": true,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "is_highlighted",
#           "type": "boolean",
#           "required": false,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         }
#       ]
#     },
#     {
#       "uid": "landing-page.pricing",
#       "category": "landing-page",
#       "displayName": "Pricing",
#       "fileName": "pricing",
#       "fields": [
#         {
#           "name": "title",
#           "type": "string",
#           "required": true,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "pricing_cards",
#           "type": "component",
#           "required": false,
#           "component": "landing-page.pricing-card",
#           "repeatable": true,
#           "multiple": false,
#           "allowedTypes": null
#         }
#       ]
#     },
#     {
#       "uid": "landing-page.faq-item",
#       "category": "landing-page",
#       "displayName": "FAQ Item",
#       "fileName": "faq-item",
#       "fields": [
#         {
#           "name": "question",
#           "type": "string",
#           "required": true,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "answer",
#           "type": "text",
#           "required": true,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         }
#       ]
#     },
#     {
#       "uid": "landing-page.faq",
#       "category": "landing-page",
#       "displayName": "FAQ",
#       "fileName": "faq",
#       "fields": [
#         {
#           "name": "title",
#           "type": "string",
#           "required": true,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "faq_items",
#           "type": "component",
#           "required": false,
#           "component": "landing-page.faq-item",
#           "repeatable": true,
#           "multiple": false,
#           "allowedTypes": null
#         }
#       ]
#     },
#     {
#       "uid": "landing-page.contact",
#       "category": "landing-page",
#       "displayName": "Contact",
#       "fileName": "contact",
#       "fields": [
#         {
#           "name": "title",
#           "type": "string",
#           "required": true,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "description",
#           "type": "text",
#           "required": false,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "form_action",
#           "type": "string",
#           "required": false,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "form_method",
#           "type": "string",
#           "required": false,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         },
#         {
#           "name": "submit_label",
#           "type": "string",
#           "required": false,
#           "component": null,
#           "repeatable": false,
#           "multiple": false,
#           "allowedTypes": null
#         }
#       ]
#     }
#   ],
#   "singleTypeAttributes": [
#     {
#       "name": "seo",
#       "type": "component",
#       "component": "shared.seo",
#       "repeatable": false,
#       "sourceSectionIndex": null
#     },
#     {
#       "name": "hero",
#       "type": "component",
#       "component": "landing-page.hero",
#       "repeatable": false,
#       "sourceSectionIndex": 1
#     },
#     {
#       "name": "features",
#       "type": "component",
#       "component": "landing-page.features",
#       "repeatable": false,
#       "sourceSectionIndex": 2
#     },
#     {
#       "name": "testimonials",
#       "type": "component",
#       "component": "landing-page.testimonials",
#       "repeatable": false,
#       "sourceSectionIndex": 3
#     },
#     {
#       "name": "pricing",
#       "type": "component",
#       "component": "landing-page.pricing",
#       "repeatable": false,
#       "sourceSectionIndex": 4
#     },
#     {
#       "name": "faq",
#       "type": "component",
#       "component": "landing-page.faq",
#       "repeatable": false,
#       "sourceSectionIndex": 5
#     },
#     {
#       "name": "contact",
#       "type": "component",
#       "component": "landing-page.contact",
#       "repeatable": false,
#       "sourceSectionIndex": 6
#     }
#   ],
#   "seedData": {
#     "seo": {
#       "meta_title": "LaunchFlow - Modern Landing Page Platform"
#     },
#     "hero": {
#       "eyebrow": "Launch faster with less busywork",
#       "title": "Build beautiful landing pages without rebuilding your CMS",
#       "description": "LaunchFlow helps teams publish campaigns, capture leads, and manage content from one simple workspace.",
#       "primary_cta": {
#         "text": "View plans",
#         "url": "#pricing"
#       },
#       "secondary_cta": {
#         "text": "Explore features",
#         "url": "#features"
#       },
#       "image": {
#         "src": "images/dashboard-preview.png",
#         "alt": "LaunchFlow dashboard preview"
#       }
#     },
#     "features": {
#       "title": "Everything your team needs to launch",
#       "description": "Reusable tools for marketing pages, lead capture, analytics, and publishing workflows.",
#       "items": [
#         {
#           "title": "Reusable page sections",
#           "description": "Create heroes, cards, FAQs, forms, and footers once, then reuse them across campaigns.",
#           "image": null,
#           "cta": null
#         },
#         {
#           "title": "Lead capture forms",
#           "description": "Collect qualified leads with forms that connect directly to your campaign workspace.",
#           "image": null,
#           "cta": null
#         },
#         {
#           "title": "Content approval flow",
#           "description": "Preview changes, request edits, and publish only when your team is ready.",
#           "image": null,
#           "cta": null
#         }
#       ]
#     },
#     "testimonials": {
#       "title": "Trusted by growing teams",
#       "description": "",
#       "items": [
#         {
#           "quote": "\"LaunchFlow helped us ship three campaign pages in a week without waiting on engineering.\"",
#           "author_name": "Maya Kapoor",
#           "author_role": "Head of Growth, BrightCart"
#         },
#         {
#           "quote": "\"The reusable content model made our landing pages easier to manage and much faster to update.\"",
#           "author_name": "Daniel Brooks",
#           "author_role": "Marketing Lead, Northstar Labs"
#         }
#       ]
#     },
#     "pricing": {
#       "title": "Simple pricing for every stage",
#       "description": "",
#       "items": [
#         {
#           "title": "Starter",
#           "price": "$19/month",
#           "description": "For solo founders and small teams testing new ideas.",
#           "features": [
#             {
#               "text": "3 active landing pages"
#             },
#             {
#               "text": "Basic lead forms"
#             },
#             {
#               "text": "Email support"
#             }
#           ],
#           "is_highlighted": false
#         },
#         {
#           "title": "Growth",
#           "price": "$79/month",
#           "description": "For teams running multiple campaigns and experiments.",
#           "features": [
#             {
#               "text": "Unlimited landing pages"
#             },
#             {
#               "text": "Advanced approval flow"
#             },
#             {
#               "text": "Priority support"
#             }
#           ],
#           "is_highlighted": true
#         },
#         {
#           "title": "Scale",
#           "price": "Custom",
#           "description": "For larger organizations with custom publishing needs.",
#           "features": [
#             {
#               "text": "Dedicated workspace setup"
#             },
#             {
#               "text": "Custom integrations"
#             },
#             {
#               "text": "Success manager"
#             }
#           ],
#           "is_highlighted": false
#         }
#       ]
#     },
#     "faq": {
#       "title": "Frequently asked questions",
#       "description": "",
#       "items": [
#         {
#           "question": "Can I reuse sections across pages?",
#           "answer": "Yes. LaunchFlow is designed around reusable sections that can be managed from a CMS."
#         },
#         {
#           "question": "Do I need a developer to publish updates?",
#           "answer": "No. Your team can preview and publish content updates through the workspace."
#         },
#         {
#           "question": "Can I export campaign data?",
#           "answer": "Yes. Leads and campaign data can be exported for analysis or synced to other tools."
#         }
#       ]
#     },
#     "contact": {
#       "title": "Talk to our team",
#       "description": "Tell us what you want to launch and we will help you choose the right plan.",
#       "form": {
#         "action": "/contact",
#         "method": "post",
#         "submit_label": "Request demo",
#         "fields": [
#           {
#             "label": "Name",
#             "name": "name",
#             "input_type": "text",
#             "required": true
#           },
#           {
#             "label": "Email",
#             "name": "email",
#             "input_type": "email",
#             "required": true
#           },
#           {
#             "label": "Company",
#             "name": "company",
#             "input_type": "text",
#             "required": false
#           },
#           {
#             "label": "Message",
#             "name": "message",
#             "input_type": "textarea",
#             "required": false
#           }
#         ]
#       }
#     }
#   },
#   "warnings": [
#     "Contact form fields are stored as structured JSON in the contact component; Strapi does not natively model dynamic form field schemas, so consider a dedicated form builder or custom component if field-level editing is required.",
#     "Added missing seo singleTypeAttribute for seedData.seo."
#   ]
# }
